# %%
# import dependencies
import pandas as pd
import gmaps
from sqlalchemy import create_engine
from config import api_key
from urllib import response
import requests
import json
import numpy as np

# %% [markdown]
# ### store CSV data into a DataFrame
# ##### In this project, we were keen to evaluate Airbnb data sourced from Kaggle. Airbnb datasets were downloaded in a CSV format, read into pandas and cleaned to have relevant dataframes

# %%
# read the csv into pandas
listing_df=pd.read_csv('resources/listings.csv')
listing_df.head()
len(listing_df)
# Out:
# 20420

# %%
# select the most desired columns to be stored in sql databse
# perform necessary cleaning routines
# due to the dataset being large, the team opted for top 100 airbnb's in melbourne
new_df=listing_df[['id', 'host_id', 'name', 'host_location', 'review_scores_location', \
    'latitude', 'longitude', 'price']]
new_df.rename(columns={'name':'airbnb_name'}, inplace=True)
new_df.sort_values(by=['review_scores_location'], ascending=False)
new_df=new_df.head(100)
new_df.head()
# Out:
# /Users/russ/opt/anaconda3/envs/bootcamp/lib/python3.7/site-packages/pandas/core/frame.py:5047: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#       id  host_id                                    airbnb_name  \
# 0   9835    33057                         Beautiful Room & House
# 1  10803    38901  Room in Cool Deco Apartment in Brunswick East
# 2  12936    50121         St Kilda 1BR+BEACHSIDE+BALCONY+WIFI+AC
# 3  38271   164193             Melbourne - Old Trafford Apartment
# 4  41836   182833              CLOSE TO CITY & MELBOURNE AIRPORT
#
#                     host_location  review_scores_location  latitude  \
# 0                              AU                     9.0 -37.77268
# 1  Melbourne, Victoria, Australia                    10.0 -37.76651
# 2  Melbourne, Victoria, Australia                    10.0 -37.85999
# 3    Berwick, Victoria, Australia                    10.0 -38.05725
# 4  Melbourne, Victoria, Australia                     9.0 -37.69729
#
#    longitude   price
# 0  145.09213  $60.00
# 1  144.98074  $31.00
# 2  144.97662  $95.00
# 3  145.33936  $99.00
# 4  145.00082  $40.00

# %%
# read in the csv dataset
reviews_df=pd.read_csv('resources/reviews.csv', encoding='utf-8')
reviews_df.head()
# Out:
#    listing_id        id        date  reviewer_id reviewer_name  \
# 0        9835    279854  2011-05-24       560832        Miriam
# 1        9835   3640746  2013-02-26      5143343      Michelle
# 2        9835  23731188  2014-12-08      2478713         Karyn
# 3        9835  46588875  2015-09-12     26184717      Rosalind
# 4       10803   3333588  2013-01-12      4421189      Johannes
#
#                                             comments
# 0             Very hospitable, much appreciated.\r\n
# 1  A beautiful house in a lovely quiet neighbourh...
# 2  This was my first time using airbnb and it was...
# 3  I was visiting Melbourne to spend time with my...
# 4  It was very convenient  to stay in Lindsay's a...

# %%
# extracted the needed columns to be stored in sql database
new_df3=reviews_df[['listing_id', 'id', 'comments']]
new_df3.head()
# Out:
#    listing_id        id                                           comments
# 0        9835    279854             Very hospitable, much appreciated.\r\n
# 1        9835   3640746  A beautiful house in a lovely quiet neighbourh...
# 2        9835  23731188  This was my first time using airbnb and it was...
# 3        9835  46588875  I was visiting Melbourne to spend time with my...
# 4       10803   3333588  It was very convenient  to stay in Lindsay's a...

# %% [markdown]
# ### extract data from Google API
# ##### This provided restaurant information near the targeted Airbnb locations. Also cleaned and formatted for further usage.
# ##### Reason for extracting this data was to enable further analysis on where Airbnb guest might like to dine from or order takeouts from, the group thought this would be of keen interests to guests and hosts.

# %%
# create a new dataframe to append extracted restaurant details
# notice we have empty columns which will be filled after parsing in the API
# maintained 'id' column to establish relationship in sql database as primary key
cafe_df=new_df[['id','airbnb_name','latitude','longitude']]
cafe_df['cafe_name']=''
cafe_df['cafe_rating']=''
cafe_df
# Out:
# /Users/russ/opt/anaconda3/envs/bootcamp/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /Users/russ/opt/anaconda3/envs/bootcamp/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#         id                                     airbnb_name  latitude  \
# 0     9835                          Beautiful Room & House -37.77268
# 1    10803   Room in Cool Deco Apartment in Brunswick East -37.76651
# 2    12936          St Kilda 1BR+BEACHSIDE+BALCONY+WIFI+AC -37.85999
# 3    38271              Melbourne - Old Trafford Apartment -38.05725
# 4    41836               CLOSE TO CITY & MELBOURNE AIRPORT -37.69729
# ..     ...                                             ...       ...
# 95  449585             Need Luxury Homebase in Melbourne 1 -37.80491
# 96  453940  Corner room - Private & Lovely Balwyn Nth Home -37.79559
# 97  456950                              St Kilda Bay Views -37.85397
# 98  464528               BOUTIQUE STAYS – Zinc Views - 501 -37.84318
# 99  464612       Point Cook Homestay with Private Bathroom -37.90042
#
#     longitude cafe_name cafe_rating
# 0   145.09213
# 1   144.98074
# 2   144.97662
# 3   145.33936
# 4   145.00082
# ..        ...       ...         ...
# 95  145.05325
# 96  145.07892
# 97  144.98198
# 98  144.94016
# 99  144.72496
#
# [100 rows x 6 columns]

# %%
# params dictionary to update
params={
    'radius':20,
    'types':'restaurant',
    'keyword':'restaurant',
    'key':api_key
}

# use coordinates from cafe_db dataframe
for index, row in cafe_df.iterrows():
    lat=row['latitude']
    lng=row['longitude']

    params['location']=f'{lat},{lng}'

    url='https://maps.googleapis.com/maps/api/place/nearbysearch/json'

    response=requests.get(url, params=params).json()

    # print(json.dumps(response, indent=4, sort_keys=True))

    try:
        cafe_df.loc[index,'cafe_name']=response['results'][0]['name']
        cafe_df.loc[index, 'cafe_rating']=response['results'][0]['rating']

    except(KeyError, IndexError):
        print('stay put as we keep searching for a nearby cafe')
# Out:
# /Users/russ/opt/anaconda3/envs/bootcamp/lib/python3.7/site-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# stay put as we keep searching for a nearby cafe
# stay put as we keep searching for a nearby cafe
# stay put as we keep searching for a nearby cafe
# stay put as we keep searching for a nearby cafe
# stay put as we keep searching for a nearby cafe
# stay put as we keep searching for a nearby cafe
# stay put as we keep searching for a nearby cafe
# stay put as we keep searching for a nearby cafe
# stay put as we keep searching for a nearby cafe
# stay put as we keep searching for a nearby cafe
# stay put as we keep searching for a nearby cafe
# stay put as we keep searching for a nearby cafe
# stay put as we keep searching for a nearby cafe
# stay put as we keep searching for a nearby cafe
# stay put as we keep searching for a nearby cafe
# stay put as we keep searching for a nearby cafe
# stay put as we keep searching for a nearby cafe
# stay put as we keep searching for a nearby cafe
# stay put as we keep searching for a nearby cafe
# stay put as we keep searching for a nearby cafe
# stay put as we keep searching for a nearby cafe
# stay put as we keep searching for a nearby cafe
# stay put as we keep searching for a nearby cafe
# stay put as we keep searching for a nearby cafe
# stay put as we keep searching for a nearby cafe
# stay put as we keep searching for a nearby cafe
# stay put as we keep searching for a nearby cafe
# stay put as we keep searching for a nearby cafe
# stay put as we keep searching for a nearby cafe
# stay put as we keep searching for a nearby cafe
# stay put as we keep searching for a nearby cafe
# stay put as we keep searching for a nearby cafe
# stay put as we keep searching for a nearby cafe
# stay put as we keep searching for a nearby cafe
# stay put as we keep searching for a nearby cafe
# stay put as we keep searching for a nearby cafe
# stay put as we keep searching for a nearby cafe
# stay put as we keep searching for a nearby cafe
# stay put as we keep searching for a nearby cafe
# stay put as we keep searching for a nearby cafe
# stay put as we keep searching for a nearby cafe
# stay put as we keep searching for a nearby cafe
# stay put as we keep searching for a nearby cafe

# %%
# clean the extracted data in the cafe df
cafe_df['cafe_name'].replace('', np.nan, inplace=True)
# cafe_df['cafe rating'].replace('', np.nan, inplace=True)
cafe_df.dropna(subset=['cafe_name'], inplace=True)
cafe_df
# Out:
# /Users/russ/opt/anaconda3/envs/bootcamp/lib/python3.7/site-packages/pandas/core/generic.py:6619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)
# /Users/russ/opt/anaconda3/envs/bootcamp/lib/python3.7/site-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
# 90  432113   Split Level City Centre Apartment + free parking -37.82761
# 91  433779                      Room with private courtyard 7 -37.88427
# 92  438849                  Grand Old Victorian Hawthorn Home -37.82406
# 93  438899  Uber-Cool Loft-South Melbourne-Wkly&Mthly Pricing -37.83359
# 97  456950                                 St Kilda Bay Views -37.85397
# 98  464528                  BOUTIQUE STAYS – Zinc Views - 501 -37.84318
# 99  464612          Point Cook Homestay with Private Bathroom -37.90042
#
#     longitude                               cafe_name cafe_rating
# 0   145.09213                Mulino Woodfire Pizzeria         4.6
# 2   144.97662                     Leo's Spaghetti Bar         4.1
# 3   145.33936                    Masala Bar and Grill         3.7
# 5   145.11447                    Tarantino's Pizzeria         4.4
# 7   145.00442                             Bouzy Rouge         4.4
# 8   144.96267                                 Tipo 00         4.6
# 11  145.03396                     Dawson Eatery & Bar         4.5
# 14  145.08541                               BANG BANG         4.4
# 15  144.97946                             Trippy Taco         4.3
# 16  144.97616                    Bon Ap' Petit Bistro         4.6
# 17  144.93640    Isshin Izakaya - Japanese Restaurant         3.8
# 18  144.99012                      Marmara Restaurant         4.5
# 22  144.96606                         Lane Restaurant         4.4
# 24  145.07744                  Buono Restaurant & Bar         4.9
# 25  144.94031                 Hanoi Mee Kitchen & Bar         4.6
# 27  144.97929                       Rosco's @ Chevron         4.5
# 28  144.97942                             Trippy Taco         4.3
# 31  145.03991          Oreganos Pasta & Pizza Ivanhoe         4.3
# 35  145.05913                        Mylyn Restaurant         4.2
# 37  144.97712                     Leo's Spaghetti Bar         4.1
# 39  145.02775        The Potsticker - Caulfield North           4
# 40  144.98633  OZZYTHAI, ST KILDA Cafe Bar Restaurant         4.4
# 41  145.12380                              Montibello         4.4
# 45  144.95190                      Amiconi Restaurant         4.7
# 48  144.97908                    Bon Ap' Petit Bistro         4.6
# 52  145.02439                Junoon Indian Restaurant         4.6
# 54  144.98274                           Fonda Mexican         4.2
# 56  144.96145                             My Goodness         4.2
# 57  144.95213                      Amiconi Restaurant         4.7
# 58  144.96295                     Kim Sing Restaurant         4.4
# 59  145.14081                        Lexton Lunch Box         4.3
# 61  144.99285                          Cafe Republic.         4.3
# 63  144.98937                              FIGO Pizza         4.5
# 64  144.98213                 Sook Thai Kitchen & Bar         4.8
# 65  144.97883                              Little Hop         4.6
# 67  144.75729                             BBQ Chicken         3.7
# 69  144.96606                 Encore Restaurant & Bar         4.6
# 70  145.00078                    Silvio's Pizza House           4
# 71  144.99518                       The Happy Mexican         4.5
# 73  144.75728                             BBQ Chicken         3.7
# 74  144.87123                       Motorino Pizzeria         4.6
# 76  144.96180                             My Goodness         4.2
# 77  144.89165                       Abesha Restaurant         4.6
# 78  145.06378                            District Pho         4.7
# 80  144.98305                           Fonda Mexican         4.2
# 81  144.99824         Zanini Pizzeria - St Kilda East         4.5
# 83  145.03969                               Centonove         4.7
# 85  145.03505                         Le Petit Bistro         4.5
# 87  145.06133                     Gami Chicken & Beer         4.4
# 88  145.05335                 Squires Loft Camberwell         4.2
# 90  144.96765                               Ayam Chef         4.4
# 91  145.06139                     Gami Chicken & Beer         4.4
# 92  145.05656                              Hunger Den         4.7
# 93  144.96480            KUU Café + Japanese kitchen.         4.4
# 97  144.98198                             My Goodness         4.1
# 98  144.94016                 Hanoi Mee Kitchen & Bar         4.6
# 99  144.72496                          Pizza Industri         4.4

# %% [markdown]
# ### Connecting to local database

# %%
connection_string='postgres:Harvey90@localhost:5432/etl_project'
engine=create_engine(f'postgresql://{connection_string}')

# %%
# confirm tables
engine.table_names()
# Out:
# /Users/russ/opt/anaconda3/envs/bootcamp/lib/python3.7/site-packages/ipykernel_launcher.py:2: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
# ['listing', 'reviews', 'cafes']

# %%
new_df.to_sql(name='listing', con=engine, if_exists='append', index=False)

# %%
cafe_df.to_sql(name='cafes', con=engine, if_exists='append', index=False)

# %%
new_df3.to_sql(name='reviews', con=engine, if_exists='append', index=False)

# %%
pd.read_sql_query('select * from listing', con=engine).head()
# Out:
#       id  host_id                                    airbnb_name  \
# 0   9835    33057                         Beautiful Room & House
# 1  10803    38901  Room in Cool Deco Apartment in Brunswick East
# 2  12936    50121         St Kilda 1BR+BEACHSIDE+BALCONY+WIFI+AC
# 3  38271   164193             Melbourne - Old Trafford Apartment
# 4  41836   182833              CLOSE TO CITY & MELBOURNE AIRPORT
#
#                     host_location  review_scores_location  latitude  \
# 0                              AU                     9.0 -37.77268
# 1  Melbourne, Victoria, Australia                    10.0 -37.76651
# 2  Melbourne, Victoria, Australia                    10.0 -37.85999
# 3    Berwick, Victoria, Australia                    10.0 -38.05725
# 4  Melbourne, Victoria, Australia                     9.0 -37.69729
#
#    longitude   price
# 0  145.09213  $60.00
# 1  144.98074  $31.00
# 2  144.97662  $95.00
# 3  145.33936  $99.00
# 4  145.00082  $40.00

# %%
pd.read_sql_query('select * from reviews', con=engine).head()
# Out:
#          id  listing_id                                           comments
# 0    279854        9835             Very hospitable, much appreciated.\r\n
# 1   3640746        9835  A beautiful house in a lovely quiet neighbourh...
# 2  23731188        9835  This was my first time using airbnb and it was...
# 3  46588875        9835  I was visiting Melbourne to spend time with my...
# 4   3333588       10803  It was very convenient  to stay in Lindsay's a...

# %%
pd.read_sql_query('select * from cafes', con=engine).head()
# Out:
#       id                                        airbnb_name  latitude  \
# 0   9835                             Beautiful Room & House -37.77268
# 1  12936             St Kilda 1BR+BEACHSIDE+BALCONY+WIFI+AC -37.85999
# 2  38271                 Melbourne - Old Trafford Apartment -38.05725
# 3  43429  Tranquil Javanese-Style Apartment in Oakleigh ... -37.89960
# 4  47100                 Très Charming in Fabulous Richmond -37.81804
#
#    longitude                 cafe_name  cafe_rating
# 0  145.09213  Mulino Woodfire Pizzeria          4.6
# 1  144.97662       Leo's Spaghetti Bar          4.1
# 2  145.33936      Masala Bar and Grill          3.7
# 3  145.11447      Tarantino's Pizzeria          4.4
# 4  145.00442               Bouzy Rouge          4.4
