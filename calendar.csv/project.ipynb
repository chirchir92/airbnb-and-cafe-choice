# %%
import pandas as pd
import os 
from sodapy import Socrata
import gmaps

# %%
df=pd.read_csv("../calendar.csv/calendar.csv", encoding="utf8")
calendar_df=df.drop(columns=['date','available', 'adjusted_price', 'minimum_nights', 'maximum_nights'])

calendar_df.head()
# Out:
#    listing_id   price
# 0      875444  $75.00
# 1      875444  $81.00
# 2      875444  $81.00
# 3      875444  $75.00
# 4      875444  $75.00

# %%
d1=calendar_df.groupby('listing_id')['price'].nunique()
d1.head()
# Out:
# listing_id
# 9835     1
# 10803    1
# 12936    6
# 38271    1
# 41836    6
# Name: price, dtype: int64

# %%
df1=pd.read_csv("../reviews.csv", encoding="utf8")
df1.head()
# Out:
#    listing_id        id        date  reviewer_id reviewer_name  \
# 0        9835    279854  2011-05-24       560832        Miriam
# 1        9835   3640746  2013-02-26      5143343      Michelle
# 2        9835  23731188  2014-12-08      2478713         Karyn
# 3        9835  46588875  2015-09-12     26184717      Rosalind
# 4       10803   3333588  2013-01-12      4421189      Johannes
#
#                                             comments
# 0             Very hospitable, much appreciated.\r\n
# 1  A beautiful house in a lovely quiet neighbourh...
# 2  This was my first time using airbnb and it was...
# 3  I was visiting Melbourne to spend time with my...
# 4  It was very convenient  to stay in Lindsay's a...

# %%
df2=pd.read_csv("../listings.csv", encoding="utf8")
df2.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0   9835   https://www.airbnb.com/rooms/9835  20200820034003   2020-08-21
# 1  10803  https://www.airbnb.com/rooms/10803  20200820034003   2020-08-20
# 2  12936  https://www.airbnb.com/rooms/12936  20200820034003   2020-08-20
# 3  38271  https://www.airbnb.com/rooms/38271  20200820034003   2020-08-21
# 4  41836  https://www.airbnb.com/rooms/41836  20200820034003   2020-08-22
#
#                                             name  \
# 0                         Beautiful Room & House
# 1  Room in Cool Deco Apartment in Brunswick East
# 2         St Kilda 1BR+BEACHSIDE+BALCONY+WIFI+AC
# 3             Melbourne - Old Trafford Apartment
# 4              CLOSE TO CITY & MELBOURNE AIRPORT
#
#                                          description  \
# 0  <b>The space</b><br />House: Clean, New, Moder...
# 1  A large air conditioned room with queen spring...
# 2  RIGHT IN THE HEART OF ST KILDA! It doesn't get...
# ...

# %%
client = Socrata("data.melbourne.vic.gov.au", app_token='zxKy8sLmqhCxio8QHuxhpWnYR',
                    username='russ.cheru@gmail.com', password='Harvey90')
results = client.get("xt2y-tnn9", limit=2000)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)
results_df.head()
# Out:
#   census_year block_id property_id base_property_id  \
# 0        2002        2      111467           103973
# 1        2002        2      111467           103973
# 2        2002        4      103972           103972
# 3        2002        4      103972           103972
# 4        2002        4      103972           103972
#
#                            street_address  clue_small_area  \
# 0            0 King Street MELBOURNE 3000  Melbourne (CBD)
# 1            0 King Street MELBOURNE 3000  Melbourne (CBD)
# 2  363-397 Flinders Street MELBOURNE 3000  Melbourne (CBD)
# 3  363-397 Flinders Street MELBOURNE 3000  Melbourne (CBD)
# 4  363-397 Flinders Street MELBOURNE 3000  Melbourne (CBD)
#
#                                       trading_name industry_anzsic4_code  \
# 0               469-479 King Street MELBOURNE 3000                  8921
# 1               469-479 King Street MELBOURNE 3000                  8921
# ...
